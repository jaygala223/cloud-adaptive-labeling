# %%
from datasets import load_dataset

dataset = load_dataset("jaygala223/38-cloud-train-only-v2")

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 8400
#     })
# })

# %%
dataset['train'][36]['image']
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=384x384>

# %%
index = 35

dataset['train'][index]['image'].save(f'./new_png_labels_and_images/{index}.png')
